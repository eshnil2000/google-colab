# %% [markdown]
# # Nearest Neighbor Example
#
# A nearest neighbor learning algorithm example using TensorFlow library.
# This example is using the MNIST database of handwritten digits (http://yann.lecun.com/exdb/mnist/)
#
# - Author: Aymeric Damien
# - Project: https://github.com/aymericdamien/TensorFlow-Examples/

# %%
# !pip install numpy tensorflow
import numpy as np
import tensorflow as tf

# Import MINST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)
# Out:
# Collecting numpy
#   Downloading https://files.pythonhosted.org/packages/fc/d1/45be1144b03b6b1e24f9a924f23f66b4ad030d834ad31fb9e5581bd328af/numpy-1.16.4-cp37-cp37m-manylinux1_x86_64.whl (17.3MB)
#      |████████████████████████████████| 17.3MB 3.4MB/s eta 0:00:01
# Collecting tensorflow
#   Downloading https://files.pythonhosted.org/packages/f4/28/96efba1a516cdacc2e2d6d081f699c001d414cc8ca3250e6d59ae657eb2b/tensorflow-1.14.0-cp37-cp37m-manylinux1_x86_64.whl (109.3MB)
#      |████████████████████████████████| 109.3MB 246kB/s  eta 0:00:01    |█████                           | 17.1MB 41.4MB/s eta 0:00:03
# Collecting tensorflow-estimator<1.15.0rc0,>=1.14.0rc0 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/3c/d5/21860a5b11caf0678fbc8319341b0ae21a07156911132e0e71bffed0510d/tensorflow_estimator-1.14.0-py2.py3-none-any.whl (488kB)
#      |████████████████████████████████| 491kB 53.6MB/s eta 0:00:01
# Collecting wrapt>=1.11.1 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/23/84/323c2415280bc4fc880ac5050dddfb3c8062c2552b34c2e512eb4aa68f79/wrapt-1.11.2.tar.gz
# Requirement already satisfied: six>=1.10.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from tensorflow) (1.12.0)
# Collecting astor>=0.6.0 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/d1/4f/950dfae467b384fc96bc6469de25d832534f6b4441033c39f914efd13418/astor-0.8.0-py2.py3-none-any.whl
# Collecting keras-applications>=1.0.6 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 22.8MB/s eta 0:00:01
# Collecting protobuf>=3.6.1 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/ce/86/9f6123c4c6f481862f286dbe13aa2e97bdedd7662f5fc3033c1a41f32f88/protobuf-3.8.0-cp37-cp37m-manylinux1_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 52.9MB/s eta 0:00:01
# Requirement already satisfied: wheel>=0.26 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from tensorflow) (0.33.4)
# Collecting absl-py>=0.7.0 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/da/3f/9b0355080b81b15ba6a9ffcf1f5ea39e307a2778b2f2dc8694724e8abd5b/absl-py-0.7.1.tar.gz (99kB)
#      |████████████████████████████████| 102kB 32.6MB/s ta 0:00:01
# Collecting grpcio>=1.8.6 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/9d/b1/b80dea9e0bbbdd07bf7ba69c6df1aeb3e88b90b85ca326c40be9e29bc37c/grpcio-1.22.0-cp37-cp37m-manylinux1_x86_64.whl (2.2MB)
#      |████████████████████████████████| 2.2MB 21.5MB/s eta 0:00:01
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/8a/48/a76be51647d0eb9f10e2a4511bf3ffb8cc1e6b14e9e4fab46173aa79f981/termcolor-1.1.0.tar.gz
# Collecting keras-preprocessing>=1.0.5 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/28/6a/8c1f62c37212d9fc441a7e26736df51ce6f0e38455816445471f10da4f0a/Keras_Preprocessing-1.1.0-py2.py3-none-any.whl (41kB)
#      |████████████████████████████████| 51kB 15.9MB/s eta 0:00:01
# Collecting tensorboard<1.15.0,>=1.14.0 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/91/2d/2ed263449a078cd9c8a9ba50ebd50123adf1f8cfbea1492f9084169b89d9/tensorboard-1.14.0-py3-none-any.whl (3.1MB)
#      |████████████████████████████████| 3.2MB 32.8MB/s eta 0:00:01
# Collecting gast>=0.2.0 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Collecting google-pasta>=0.1.6 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/d0/33/376510eb8d6246f3c30545f416b2263eee461e40940c2a4413c711bdf62d/google_pasta-0.1.7-py3-none-any.whl (52kB)
#      |████████████████████████████████| 61kB 26.4MB/s eta 0:00:01
# Collecting h5py (from keras-applications>=1.0.6->tensorflow)
#   Downloading https://files.pythonhosted.org/packages/8e/fd/2ca5c4f4ed33ac4178f9c4d551e3946ab480866e3cd67a65a67a4bb35367/h5py-2.9.0-cp37-cp37m-manylinux1_x86_64.whl (2.8MB)
#      |████████████████████████████████| 2.8MB 40.9MB/s eta 0:00:01
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.7/site-packages (from protobuf>=3.6.1->tensorflow) (41.0.1)
# Collecting werkzeug>=0.11.15 (from tensorboard<1.15.0,>=1.14.0->tensorflow)
#   Downloading https://files.pythonhosted.org/packages/9f/57/92a497e38161ce40606c27a86759c6b92dd34fcdb33f64171ec559257c02/Werkzeug-0.15.4-py2.py3-none-any.whl (327kB)
#      |████████████████████████████████| 327kB 35.2MB/s eta 0:00:01
# Collecting markdown>=2.6.8 (from tensorboard<1.15.0,>=1.14.0->tensorflow)
#   Downloading https://files.pythonhosted.org/packages/c0/4e/fd492e91abdc2d2fcb70ef453064d980688762079397f779758e055f6575/Markdown-3.1.1-py2.py3-none-any.whl (87kB)
#      |████████████████████████████████| 92kB 21.4MB/s eta 0:00:01
# Building wheels for collected packages: wrapt, absl-py, termcolor, gast
#   Building wheel for wrapt (setup.py) ... done
#   Stored in directory: /home/jovyan/.cache/pip/wheels/d7/de/2e/efa132238792efb6459a96e85916ef8597fcb3d2ae51590dfd
#   Building wheel for absl-py (setup.py) ... done
#   Stored in directory: /home/jovyan/.cache/pip/wheels/ee/98/38/46cbcc5a93cfea5492d19c38562691ddb23b940176c14f7b48
#   Building wheel for termcolor (setup.py) ... done
#   Stored in directory: /home/jovyan/.cache/pip/wheels/7c/06/54/bc84598ba1daf8f970247f550b175aaaee85f68b4b0c5ab2c6
#   Building wheel for gast (setup.py) ... done
#   Stored in directory: /home/jovyan/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built wrapt absl-py termcolor gast
# Installing collected packages: numpy, tensorflow-estimator, wrapt, astor, h5py, keras-applications, protobuf, absl-py, grpcio, termcolor, keras-preprocessing, werkzeug, markdown, tensorboard, gast, google-pasta, tensorflow
# Successfully installed absl-py-0.7.1 astor-0.8.0 gast-0.2.2 google-pasta-0.1.7 grpcio-1.22.0 h5py-2.9.0 keras-applications-1.0.8 keras-preprocessing-1.1.0 markdown-3.1.1 numpy-1.16.4 protobuf-3.8.0 tensorboard-1.14.0 tensorflow-1.14.0 tensorflow-estimator-1.14.0 termcolor-1.1.0 werkzeug-0.15.4 wrapt-1.11.2
# WARNING: Logging before flag parsing goes to stderr.
# W0710 11:11:42.535877 140498881800000 deprecation.py:323] From <ipython-input-2-84c71aca02e8>:7: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# W0710 11:11:42.538416 140498881800000 deprecation.py:323] From /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# W0710 11:11:42.539878 140498881800000 deprecation.py:323] From /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# W0710 11:11:42.733598 140498881800000 deprecation.py:323] From /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# W0710 11:11:43.041536 140498881800000 deprecation.py:323] From /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# W0710 11:11:43.044140 140498881800000 deprecation.py:323] From /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# W0710 11:11:43.165131 140498881800000 deprecation.py:323] From /srv/conda/envs/notebook/lib/python3.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
# In this example, we limit mnist data
Xtr, Ytr = mnist.train.next_batch(5000) #5000 for training (nn candidates)
Xte, Yte = mnist.test.next_batch(200) #200 for testing

# tf Graph Input
xtr = tf.placeholder("float", [None, 784])
xte = tf.placeholder("float", [784])

# Nearest Neighbor calculation using L1 Distance
# Calculate L1 Distance
distance = tf.reduce_sum(tf.abs(tf.add(xtr, tf.negative(xte))), reduction_indices=1)
# Prediction: Get min distance index (Nearest neighbor)
pred = tf.argmin(distance, 0)

accuracy = 0.

# Initialize the variables (i.e. assign their default value)
init = tf.global_variables_initializer()

# %%
# Start training
with tf.Session() as sess:
    sess.run(init)

    # loop over test data
    for i in range(len(Xte)):
        # Get nearest neighbor
        nn_index = sess.run(pred, feed_dict={xtr: Xtr, xte: Xte[i, :]})
        # Get nearest neighbor class label and compare it to its true label
        print("Test", i, "Prediction:", np.argmax(Ytr[nn_index]), \
            "True Class:", np.argmax(Yte[i]))
        # Calculate accuracy
        if np.argmax(Ytr[nn_index]) == np.argmax(Yte[i]):
            accuracy += 1./len(Xte)
    print("Done!")
    print("Accuracy:", accuracy)
# Out:
# Test 0 Prediction: 9 True Class: 7
# Test 1 Prediction: 9 True Class: 9
# Test 2 Prediction: 9 True Class: 9
# Test 3 Prediction: 5 True Class: 5
# Test 4 Prediction: 2 True Class: 2
# Test 5 Prediction: 7 True Class: 7
# Test 6 Prediction: 9 True Class: 9
# Test 7 Prediction: 5 True Class: 5
# Test 8 Prediction: 2 True Class: 2
# Test 9 Prediction: 2 True Class: 2
# Test 10 Prediction: 1 True Class: 1
# Test 11 Prediction: 9 True Class: 9
# Test 12 Prediction: 9 True Class: 9
# Test 13 Prediction: 8 True Class: 8
# Test 14 Prediction: 4 True Class: 4
# Test 15 Prediction: 2 True Class: 2
# Test 16 Prediction: 6 True Class: 6
# Test 17 Prediction: 0 True Class: 0
# Test 18 Prediction: 9 True Class: 9
# Test 19 Prediction: 2 True Class: 2
# Test 20 Prediction: 4 True Class: 4
# Test 21 Prediction: 0 True Class: 0
# Test 22 Prediction: 2 True Class: 2
# Test 23 Prediction: 1 True Class: 1
# Test 24 Prediction: 2 True Class: 2
# Test 25 Prediction: 0 True Class: 0
# Test 26 Prediction: 9 True Class: 9
# Test 27 Prediction: 2 True Class: 2
# Test 28 Prediction: 2 True Class: 2
# Test 29 Prediction: 5 True Class: 5
# Test 30 Prediction: 3 True Class: 8
# Test 31 Prediction: 9 True Class: 9
# Test 32 Prediction: 2 True Class: 2
# Test 33 Prediction: 4 True Class: 4
# Test 34 Prediction: 5 True Class: 5
# Test 35 Prediction: 5 True Class: 5
# Test 36 Prediction: 4 True Class: 4
# Test 37 Prediction: 5 True Class: 5
# Test 38 Prediction: 5 True Class: 5
# Test 39 Prediction: 2 True Class: 2
# Test 40 Prediction: 8 True Class: 8
# Test 41 Prediction: 3 True Class: 3
# Test 42 Prediction: 5 True Class: 5
# Test 43 Prediction: 5 True Class: 5
# Test 44 Prediction: 1 True Class: 1
# Test 45 Prediction: 5 True Class: 5
# Test 46 Prediction: 2 True Class: 2
# Test 47 Prediction: 0 True Class: 0
# Test 48 Prediction: 8 True Class: 8
# Test 49 Prediction: 3 True Class: 3
# Test 50 Prediction: 6 True Class: 6
# Test 51 Prediction: 7 True Class: 7
# Test 52 Prediction: 4 True Class: 4
# Test 53 Prediction: 2 True Class: 2
# Test 54 Prediction: 4 True Class: 4
# Test 55 Prediction: 9 True Class: 7
# Test 56 Prediction: 3 True Class: 3
# Test 57 Prediction: 0 True Class: 0
# Test 58 Prediction: 3 True Class: 3
# Test 59 Prediction: 9 True Class: 9
# Test 60 Prediction: 2 True Class: 2
# Test 61 Prediction: 5 True Class: 3
# Test 62 Prediction: 4 True Class: 4
# Test 63 Prediction: 8 True Class: 8
# Test 64 Prediction: 2 True Class: 2
# Test 65 Prediction: 7 True Class: 7
# Test 66 Prediction: 4 True Class: 4
# Test 67 Prediction: 9 True Class: 9
# Test 68 Prediction: 1 True Class: 1
# Test 69 Prediction: 3 True Class: 3
# Test 70 Prediction: 7 True Class: 7
# Test 71 Prediction: 9 True Class: 9
# Test 72 Prediction: 1 True Class: 1
# Test 73 Prediction: 0 True Class: 0
# Test 74 Prediction: 7 True Class: 7
# Test 75 Prediction: 8 True Class: 8
# Test 76 Prediction: 6 True Class: 6
# Test 77 Prediction: 0 True Class: 0
# Test 78 Prediction: 9 True Class: 9
# Test 79 Prediction: 5 True Class: 5
# Test 80 Prediction: 3 True Class: 3
# Test 81 Prediction: 0 True Class: 0
# Test 82 Prediction: 0 True Class: 0
# Test 83 Prediction: 2 True Class: 2
# Test 84 Prediction: 1 True Class: 1
# Test 85 Prediction: 8 True Class: 8
# Test 86 Prediction: 2 True Class: 2
# Test 87 Prediction: 9 True Class: 9
# Test 88 Prediction: 0 True Class: 0
# Test 89 Prediction: 7 True Class: 7
# Test 90 Prediction: 3 True Class: 3
# Test 91 Prediction: 5 True Class: 5
# Test 92 Prediction: 5 True Class: 5
# Test 93 Prediction: 2 True Class: 2
# Test 94 Prediction: 4 True Class: 4
# Test 95 Prediction: 2 True Class: 2
# Test 96 Prediction: 7 True Class: 7
# Test 97 Prediction: 3 True Class: 3
# Test 98 Prediction: 4 True Class: 4
# Test 99 Prediction: 5 True Class: 5
# Test 100 Prediction: 5 True Class: 5
# Test 101 Prediction: 7 True Class: 7
# Test 102 Prediction: 5 True Class: 5
# Test 103 Prediction: 2 True Class: 2
# Test 104 Prediction: 7 True Class: 7
# Test 105 Prediction: 0 True Class: 0
# Test 106 Prediction: 3 True Class: 3
# Test 107 Prediction: 4 True Class: 4
# Test 108 Prediction: 9 True Class: 9
# Test 109 Prediction: 6 True Class: 6
# Test 110 Prediction: 8 True Class: 8
# Test 111 Prediction: 9 True Class: 9
# Test 112 Prediction: 7 True Class: 7
# Test 113 Prediction: 3 True Class: 3
# Test 114 Prediction: 7 True Class: 7
# Test 115 Prediction: 9 True Class: 9
# Test 116 Prediction: 6 True Class: 6
# Test 117 Prediction: 3 True Class: 3
# Test 118 Prediction: 1 True Class: 1
# Test 119 Prediction: 2 True Class: 2
# Test 120 Prediction: 9 True Class: 9
# Test 121 Prediction: 8 True Class: 8
# Test 122 Prediction: 7 True Class: 2
# Test 123 Prediction: 3 True Class: 3
# Test 124 Prediction: 1 True Class: 4
# Test 125 Prediction: 1 True Class: 1
# Test 126 Prediction: 6 True Class: 6
# Test 127 Prediction: 2 True Class: 2
# Test 128 Prediction: 6 True Class: 6
# Test 129 Prediction: 9 True Class: 3
# Test 130 Prediction: 2 True Class: 2
# Test 131 Prediction: 1 True Class: 1
# Test 132 Prediction: 0 True Class: 6
# Test 133 Prediction: 5 True Class: 5
# Test 134 Prediction: 7 True Class: 7
# Test 135 Prediction: 7 True Class: 7
# Test 136 Prediction: 0 True Class: 2
# Test 137 Prediction: 9 True Class: 9
# Test 138 Prediction: 8 True Class: 8
# Test 139 Prediction: 4 True Class: 4
# Test 140 Prediction: 2 True Class: 2
# Test 141 Prediction: 2 True Class: 2
# Test 142 Prediction: 4 True Class: 4
# Test 143 Prediction: 5 True Class: 5
# Test 144 Prediction: 3 True Class: 3
# Test 145 Prediction: 7 True Class: 7
# Test 146 Prediction: 7 True Class: 2
# Test 147 Prediction: 2 True Class: 2
# Test 148 Prediction: 0 True Class: 0
# Test 149 Prediction: 2 True Class: 2
# Test 150 Prediction: 4 True Class: 4
# Test 151 Prediction: 5 True Class: 5
# Test 152 Prediction: 8 True Class: 8
# Test 153 Prediction: 0 True Class: 0
# Test 154 Prediction: 3 True Class: 3
# Test 155 Prediction: 1 True Class: 1
# Test 156 Prediction: 4 True Class: 4
# Test 157 Prediction: 6 True Class: 6
# Test 158 Prediction: 0 True Class: 0
# Test 159 Prediction: 0 True Class: 0
# Test 160 Prediction: 5 True Class: 5
# Test 161 Prediction: 0 True Class: 0
# Test 162 Prediction: 1 True Class: 1
# Test 163 Prediction: 6 True Class: 6
# Test 164 Prediction: 5 True Class: 5
# Test 165 Prediction: 9 True Class: 9
# Test 166 Prediction: 9 True Class: 9
# Test 167 Prediction: 4 True Class: 4
# Test 168 Prediction: 1 True Class: 1
# Test 169 Prediction: 9 True Class: 9
# Test 170 Prediction: 3 True Class: 3
# Test 171 Prediction: 4 True Class: 4
# Test 172 Prediction: 7 True Class: 8
# Test 173 Prediction: 6 True Class: 6
# Test 174 Prediction: 4 True Class: 4
# Test 175 Prediction: 3 True Class: 3
# Test 176 Prediction: 1 True Class: 1
# Test 177 Prediction: 0 True Class: 0
# Test 178 Prediction: 0 True Class: 0
# Test 179 Prediction: 6 True Class: 6
# Test 180 Prediction: 1 True Class: 9
# Test 181 Prediction: 2 True Class: 2
# Test 182 Prediction: 1 True Class: 1
# Test 183 Prediction: 5 True Class: 5
# Test 184 Prediction: 1 True Class: 1
# Test 185 Prediction: 1 True Class: 1
# Test 186 Prediction: 2 True Class: 2
# Test 187 Prediction: 0 True Class: 0
# Test 188 Prediction: 1 True Class: 1
# Test 189 Prediction: 1 True Class: 1
# Test 190 Prediction: 6 True Class: 6
# Test 191 Prediction: 5 True Class: 5
# Test 192 Prediction: 8 True Class: 8
# Test 193 Prediction: 7 True Class: 7
# Test 194 Prediction: 6 True Class: 6
# Test 195 Prediction: 7 True Class: 7
# Test 196 Prediction: 5 True Class: 5
# Test 197 Prediction: 9 True Class: 9
# Test 198 Prediction: 4 True Class: 4
# Test 199 Prediction: 0 True Class: 0
# Done!
# Accuracy: 0.9400000000000007
