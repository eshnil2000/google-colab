# %% [markdown]
# <a href="https://colab.research.google.com/github/eshnil2000/google-colab/blob/master/ai_visualize_neural_net.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Remove directory & reinstall
# %rm -rf /content/google-colab/
# !git clone https://github.com/eshnil2000/google-colab.git

#Load the modules
import sys
sys.path.append('/content/google-colab/')
from dutils.neural_network import NeuralNetwork
from dutils.dataset import DemoDataset

#Build the Neural Network
#Number of neurons in input layer
il_nn=4
#Hidden layers: each element represents number of neurons in that layer
hl_nn = [2,2]
#Number of neurons in output layer
ol_nn = 2
nn = NeuralNetwork(il_nn,hl_nn,ol_nn)
nn.init_network()
# Out:
# Cloning into 'google-colab'...
# remote: Enumerating objects: 88, done.
# remote: Counting objects: 100% (88/88), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 88 (delta 36), reused 8 (delta 2), pack-reused 0
# Unpacking objects: 100% (88/88), done.

# %%
#Import modules for Visualization
# !pip install palettable
import dutils.VisualizeNN as VisNN
import numpy as np

# Visualize the neural Network
# Combine the input layer + hidden layers + output layers into a big matrix
network_array=hl_nn
network_array.insert(0,il_nn)
network_array.append(ol_nn)

# Print the network
print(network_array)
network=VisNN.DrawNN(np.asarray(network_array))
network.draw()
# Out:
# [4, 2, 2, 2]
